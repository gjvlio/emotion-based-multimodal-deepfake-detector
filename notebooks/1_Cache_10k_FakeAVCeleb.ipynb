# %% [markdown]
# # DeepSentinel: Incremental 10,000-Clip FakeAVCeleb Feature Cacher
#
# This notebook incrementally extracts keyframe visual embeddings ($Z_v$) and acoustic-text embeddings ($Z_{at}$) for up to **10,000 FakeAVCeleb clips** on Google Colab.
#
# ### **Auto-Save & Resumability**:
# * Every extracted feature tensor is **immediately saved directly to Google Drive** (`THESIS_MOTHERFILE/preprocessed/features/`).
# * If Colab disconnects, simply re-run this notebook! It detects already-cached files on Drive and skips them in 0 seconds, picking up right where it left off.

# %%
# Step 1: Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# Step 2: Clone repository & Install dependencies
# !rm -rf /content/thesis
# !git clone -b feat/training-turnover-prep https://github.com/gjvlio/emotion-based-multimodal-deepfake-detector.git /content/thesis
# %cd /content/thesis
# !pip install -q transformers scikit-learn tensorboard timm pandas

# %%
# Step 3: Run Incremental 10,000-Clip Feature Cacher
# !python scripts/colab_cache_fakeavceleb.py
